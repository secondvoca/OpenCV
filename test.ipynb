# %%
from skimage.io import imread
import matplotlib.pyplot as plt
from pathlib import PosixPath

path = '/mnt/c/data/IP_images'
path = PosixPath(path, 'lena.jpg')

img = imread(path)
plt.imshow(img)
